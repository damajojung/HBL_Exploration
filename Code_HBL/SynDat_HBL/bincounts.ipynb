# %% [markdown]
# # Analyse Bincounts over time

# %%
import argparse
import math
import os
import time
import random
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import *


import matplotlib.pyplot as plt
from matplotlib.lines import Line2D   

import numpy as np
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
import torch.utils

# %%
path_tz = '/Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653816041_mult0.0_dec5e-05_lr0.001_r0.3_tz.pt'
path_tz_target = '/Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653816041_mult0.0_dec5e-05_lr0.001_r0.3_tz_target.pt'

# %%
tz = torch.load(path_tz, map_location={'cuda:0': 'cpu'})
tz_target = torch.load(path_tz_target, map_location={'cuda:0': 'cpu'})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/9r/pl8035cn4cjb59msrdwcrvhr0000gn/T/ipykernel_24522/3882245643.py in <module>
# ----> 1 tz = torch.load(path_tz, map_location={'cuda:0': 'cpu'})
#       2 tz_target = torch.load(path_tz_target, map_location={'cuda:0': 'cpu'})
#
# /opt/anaconda3/envs/MasterThesis/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /opt/anaconda3/envs/MasterThesis/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
# ...

# %%
style.use('seaborn-whitegrid') 
fig = plt.figure(figsize=(15,8))
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.bar(np.arange(0,1000,1),tz, color='midnightblue', width=0.2, alpha=0.75)
plt.axhline(y=200, label= 'Amount of Samples', color = 'firebrick', alpha=0.5)
plt.legend(prop={'size': 25}, loc=1)
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel('Classes', size = 25)
plt.ylabel('Amount of Predictions', size = 25)
plt.title('Bincounts')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9r/pl8035cn4cjb59msrdwcrvhr0000gn/T/ipykernel_24522/3515607496.py in <module>
#       3 plt.rcParams["font.weight"] = "bold"
#       4 plt.rcParams["axes.labelweight"] = "bold"
# ----> 5 plt.bar(np.arange(0,1000,1),tz, color='midnightblue', width=0.2, alpha=0.75)
#       6 plt.axhline(y=200, label= 'Amount of Samples', color = 'firebrick', alpha=0.5)
#       7 plt.legend(prop={'size': 25}, loc=1)
#
# NameError: name 'tz' is not defined

# %%
style.use('seaborn-whitegrid') 
fig = plt.figure(figsize=(15,8))
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.bar(np.arange(0,1000,1),tz_target, color='midnightblue', width=0.2, alpha=0.75)
plt.axhline(y=200, label= 'Amount of Samples', color = 'firebrick', alpha=0.5)
plt.legend(prop={'size': 25}, loc=1)
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel('Classes', size = 25)
plt.ylabel('Amount of Predictions', size = 25)
plt.title('Bincounts')
plt.show()

# %% [markdown]
# # Main Entry Point

# %%
model_tz = '1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz'
model_tz_target = '1653822755_mult0.0_dec5e-05_lr0.001_r0.3_tz_target'
path = '/Users/dj/Desktop/prototypes-1000d-1000c/bincount/'

# %%
style.use('seaborn-whitegrid') 
fig = plt.figure(figsize=(15,8))
colors = ['r', 'g', 'c', 'c', 'm']

# NUM_COLORS = int(len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/'))/2)
# cm = plt.get_cmap('gist_rainbow')
# colors_arr = []
# for i in range(NUM_COLORS):
#     colors_arr.append(cm(i//1*0.1/NUM_COLORS))

for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/'))/2,1):
    # print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    # print(f'{path}{model_tz_target}_{int(i)}.pt')
    model_tz_target_load = f'{path}{model_tz_target}_{int(i)}.pt'
    # tz_target = torch.load(model_tz_target_load, map_location={'cuda:0': 'cpu'})

    # Plot tz
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    plt.bar(np.arange(0,1000,1),tz, width=0.2, alpha=0.75)
    plt.axhline(y=200, label= f'Amount of Samples {int(i)}', color = 'firebrick', alpha=0.5)
    # plt.legend(prop={'size': 25}, loc=1)
    plt.xticks(size=25)
    plt.yticks(size=25)
    plt.xlabel('Classes', size = 25)
    plt.ylabel('Amount of Predictions', size = 25)
    plt.title('Bincounts')

    #fig.savefig(f'{model_tz}.jpg')

    # # Plot tz_target
    # style.use('seaborn-whitegrid') 
    # fig = plt.figure(figsize=(15,8))
    # plt.rcParams["font.weight"] = "bold"
    # plt.rcParams["axes.labelweight"] = "bold"
    # plt.bar(np.arange(0,1000,1),tz_target, color='midnightblue', width=0.2, alpha=0.75)
    # plt.axhline(y=200, label= 'Amount of Samples', color = 'firebrick', alpha=0.5)
    # plt.legend(prop={'size': 25}, loc=1)
    # plt.xticks(size=25)
    # plt.yticks(size=25)
    # plt.xlabel('Classes', size = 25)
    # plt.ylabel('Amount of Predictions', size = 25)
    # plt.title('Bincounts')

    # fig.savefig(f'{model_tz_target}.jpg')

# %%
model_tz = '1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz'
model_tz_target = '1653822755_mult0.0_dec5e-05_lr0.001_r0.3_tz_target'
path = '/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/'

model_list = []
for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/')),1):
    print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    model_list.append(tz)
# Out:
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_0.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_1.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_2.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_3.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_4.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_5.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_6.pt
# ...

# %%
for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/')),1):
    style.use('seaborn-whitegrid') 
    fig = plt.figure(figsize=(15,8))
    # print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    print(model_tz_load)
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})
    if i % 4 == 0:
        print(torch.sum(tz))

    # Plot tz
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    plt.bar(np.arange(0,1000,1),tz, width=1.0, alpha=0.75)
    plt.axhline(y=1000, label= f'Amount of Samples {int(i)}', color = 'firebrick', alpha=0.5)
    # plt.legend(prop={'size': 25}, loc=1)
    plt.xticks(size=25)
    plt.yticks(size=25)
    plt.xlabel('Classes', size = 25)
    plt.ylabel('Amount of Predictions', size = 25)
    plt.title(f'Bincounts EPOCH {i}', size = 30)
# Out:
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_0.pt
# tensor(1000000.)
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_1.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_2.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_3.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_4.pt
# tensor(5000000.)
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_5.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_6.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_7.pt
# /Users/dj/Desktop/prototypes-1000d-1000c/bincount/1653891538_mult0.0_dec5e-05_lr0.001_r0.3_tz_8.pt
# tensor(9000000.)
# ...

# %%
NUM_COLORS = len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/'))
cm = plt.get_cmap('gist_rainbow')
colors_arr = []
for i in range(NUM_COLORS):
    colors_arr.append(cm(i//1*1.0/NUM_COLORS))

# colors = ['r', 'g', 'c', '', 'm']
z = np.arange(0,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/')*10),10)

fig = plt.figure(figsize=(35,15))
ax = fig.add_subplot(111, projection='3d')
counter = 0

for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/')),1):
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    plt.bar(np.arange(0,1000,1),tz, zs = z[counter], zdir='y', width=5.0, color=colors_arr[counter], alpha=0.8)
    counter += 1

ax.set_xlabel('Classes')
ax.set_ylabel('Epoch')
ax.set_yticklabels(np.arange(-2,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/')),2))
ax.set_zlabel('Amount of Predictions')

plt.show()
# Out:
# /opt/anaconda3/envs/MasterThesis/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
np.arange(-2,len(os.listdir('/Users/dj/Desktop/prototypes-1000d-1000c/bincount/')),2)
# Out:
# array([-2,  0,  2,  4,  6,  8, 10, 12, 14])

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [100, 80, 80, 80, 80]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize= (15,8))

ax.bar(labels, women_means, width,
       label='Women', color = 'red')
ax.bar(labels, men_means, width, label='Men')


ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
NUM_COLORS = len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/'))
cm = plt.get_cmap('gist_rainbow')
colors_arr = []
for i in range(NUM_COLORS):
    colors_arr.append(cm(i//1*1.0/NUM_COLORS))

colormap = plt.cm.get_cmap('gist_rainbow') # 'plasma' or 'viridis' or 'jet'
colormap = colormap.reversed()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
# colors = colormap(annotations)

labels = np.arange(0,1000,1)
eps = np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/')),1)
eps_amount = len(eps)
fig, ax = plt.subplots(figsize= (25,10))
plt.rcParams['axes.grid'] = False
counter = 0

for i in np.arange(len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/van_grad_bins/bincount/'))-1,-1,-1):
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    ax.bar(labels, tz, width = 5.0, label=str(eps[counter]), color = colors_arr[counter], alpha=0.8)
    counter += 1

plt.axhline(y=1000 * eps_amount, color = 'black')
sm = plt.cm.ScalarMappable(cmap=colormap)
sm.set_clim(vmin=0, vmax=NUM_COLORS)
cbar = fig.colorbar(sm)
cbar.set_label(label='Epochs',weight='bold', size = 30)
cbar.ax.tick_params(labelsize=30) 
ax.set_xlabel('Classes', size = 30)
ax.set_ylabel('Amount of Predictions', size = 30)
plt.xticks( size = 30)
plt.yticks( size = 30)

plt.show()

# %%
len(model_list[-1][model_list[-1] >= 15000])
# Out:
# 148

# %%
torch.topk(model_list[-1], 5)
# Out:
# torch.return_types.topk(
# values=tensor([295791., 224226., 214052., 197680., 179773.]),
# indices=tensor([598, 703, 681, 533,  71]))

# %% [markdown]
# # And now with clipping - r 0.01

# %%
model_tz = '1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz'
model_tz_target = '1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_target'
path = '/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/'

model_list = []
for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/')),1):
    print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    model_list.append(tz)
# Out:
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_0.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_1.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_2.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_3.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_4.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_5.pt
# /Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_6.pt
# ...

# %%
NUM_COLORS = len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/'))
cm = plt.get_cmap('gist_rainbow')
colors_arr = []
for i in range(NUM_COLORS):
    colors_arr.append(cm(i//1*1.0/NUM_COLORS))

colormap = plt.cm.get_cmap('gist_rainbow') # 'plasma' or 'viridis' or 'jet'
colormap = colormap.reversed()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
# colors = colormap(annotations)

labels = np.arange(0,1000,1)
eps = np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/')),1)
eps_amount = len(eps)
fig, ax = plt.subplots(figsize= (25,10))
plt.rcParams['axes.grid'] = False
counter = 0

for i in np.arange(len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-1000d-1000c/clipping/bincount/'))-1,-1,-1):
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    ax.bar(labels, tz, width = 5.0, label=str(eps[counter]), color = colors_arr[counter], alpha=0.8)
    counter += 1

plt.axhline(y=1000 * eps_amount, color = 'black')
sm = plt.cm.ScalarMappable(cmap=colormap)
sm.set_clim(vmin=0, vmax=NUM_COLORS)
cbar = fig.colorbar(sm)
cbar.set_label(label='Epochs',weight='bold', size = 30)
cbar.ax.tick_params(labelsize=30) 
ax.set_xlabel('Classes', size = 30)
ax.set_ylabel('Amount of Predictions', size = 30)
plt.xticks( size = 30)
plt.yticks( size = 30)

plt.show()

# %%
torch.topk(model_list[-1], 5)
# Out:
# torch.return_types.topk(
# values=tensor([154684., 101793.,  84215.,  82527.,  71736.]),
# indices=tensor([232,  68, 768, 800, 349]))

# %% [markdown]
# # And now with clipping - 1000c - 2d - r 0.3

# %%
model_tz = '1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz'
# model_tz_target = '1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_target'
path = '/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/'

model_list = []
for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/')),1):
    print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    model_list.append(tz)
# Out:
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_0.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_1.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_2.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_3.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_4.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_5.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_6.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/1654447206_mult0.0_dec5e-05_lr0.001_r0.3_tz_7.pt
# ...

# %%
NUM_COLORS = len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/'))
cm = plt.get_cmap('gist_rainbow')
colors_arr = []
for i in range(NUM_COLORS):
    colors_arr.append(cm(i//1*1.0/NUM_COLORS))

colormap = plt.cm.get_cmap('gist_rainbow') # 'plasma' or 'viridis' or 'jet'
colormap = colormap.reversed()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
# colors = colormap(annotations)

labels = np.arange(0,1000,1)
eps = np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/')),1)
eps_amount = len(eps)
fig, ax = plt.subplots(figsize= (25,10))
plt.rcParams['axes.grid'] = False
counter = 0

for i in np.arange(len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount/'))-1,-1,-1):
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    ax.bar(labels, tz, width = 5.0, label=str(eps[counter]), color = colors_arr[counter], alpha=0.8)
    counter += 1

plt.axhline(y=1000 * eps_amount, color = 'black')
sm = plt.cm.ScalarMappable(cmap=colormap)
sm.set_clim(vmin=0, vmax=NUM_COLORS)
cbar = fig.colorbar(sm)
cbar.set_label(label='Epochs',weight='bold', size = 30)
cbar.ax.tick_params(labelsize=30) 
ax.set_xlabel('Classes', size = 30)
ax.set_ylabel('Amount of Predictions', size = 30)
plt.xticks( size = 30)
plt.yticks( size = 30)

plt.show()

# %% [markdown]
# # And now with clipping - 1000c - 2d - r 5.0 long run

# %%
model_tz = '1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz'
# model_tz_target = '1653983839_mult0.0_dec5e-05_lr1e-05_r0.01_tz_target'
path = '/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/'

model_list = []
for i in np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/')),1):
    print(f'{path}{model_tz}_{int(i)}.pt')
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    model_list.append(tz)
# Out:
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_0.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_1.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_2.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_3.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_4.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_5.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_6.pt
# /Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/1654515142_mult0.0_dec5e-05_lr0.001_r5.0_tz_7.pt
# ...

# %%
NUM_COLORS = len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/'))
cm = plt.get_cmap('gist_rainbow')
colors_arr = []
for i in range(NUM_COLORS):
    colors_arr.append(cm(i//1*1.0/NUM_COLORS))

colormap = plt.cm.get_cmap('gist_rainbow') # 'plasma' or 'viridis' or 'jet'
colormap = colormap.reversed()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
# colors = colormap(annotations)

labels = np.arange(0,1000,1)
eps = np.arange(0,len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/')),1)
eps_amount = len(eps)
fig, ax = plt.subplots(figsize= (25,10))
plt.rcParams['axes.grid'] = False
counter = 0

for i in np.arange(len(os.listdir('/Users/dj/Desktop/experiments_results/prototypes-2d-1000c/bincount_1/'))-1,-1,-1):
    model_tz_load = f'{path}{model_tz}_{int(i)}.pt'
    tz = torch.load(model_tz_load, map_location={'cuda:0': 'cpu'})

    ax.bar(labels, tz, width = 5.0, label=str(eps[counter]), color = colors_arr[counter], alpha=0.8)
    counter += 1

plt.axhline(y=1000 * eps_amount, color = 'black')
sm = plt.cm.ScalarMappable(cmap=colormap)
sm.set_clim(vmin=0, vmax=NUM_COLORS)
cbar = fig.colorbar(sm)
cbar.set_label(label='Epochs',weight='bold', size = 30)
cbar.ax.tick_params(labelsize=30) 
ax.set_xlabel('Classes', size = 30)
ax.set_ylabel('Amount of Predictions', size = 30)
plt.xticks( size = 30)
plt.yticks( size = 30)

plt.show()
